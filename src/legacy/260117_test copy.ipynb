# %%
from kspec_adc_controller.adc_actions import AdcActions
controller = AdcActions()
# Out:
# 2026-01-17 15:02:03,100 [INFO] Starting the process to find devices... (at adc_actions.py)
# 2026-01-17 15:02:08,411 [INFO] Found bus hardware ID 0: BusHardwareId(Wi-Fi (Intel(R) Wi-Fi 6E AX211 160MHz)) [bus hardware: Network Adapter, protocol: EtherCAT, hardware specifier: {85B9F7EF-9B8F-408F-ABBC-374426446F5C}] (at adc_actions.py)
# 2026-01-17 15:02:08,414 [INFO] Found bus hardware ID 1: BusHardwareId(Serial Port (COM6)) [bus hardware: Serial Port, protocol: MODBUS RTU, hardware specifier: COM6] (at adc_actions.py)
# 2026-01-17 15:02:08,415 [INFO] Found bus hardware ID 2: BusHardwareId(USB Bus) [bus hardware: USB BUS, protocol: MODBUS VCP, hardware specifier: UsbRoot0, extra hardware specifier: UsbBusVcp] (at adc_actions.py)
# 2026-01-17 15:02:08,417 [INFO] Found bus hardware ID 3: BusHardwareId(Wi-Fi (Intel(R) Wi-Fi 6E AX211 160MHz)) [bus hardware: Network Adapter, protocol: MODBUS TCP, hardware specifier: {85B9F7EF-9B8F-408F-ABBC-374426446F5C}] (at adc_actions.py)
# 2026-01-17 15:02:08,419 [INFO] Found bus hardware ID 4: BusHardwareId(Wi-Fi (Intel(R) Wi-Fi 6E AX211 160MHz)) [bus hardware: Network Adapter, protocol: RESTful API, hardware specifier: {85B9F7EF-9B8F-408F-ABBC-374426446F5C}] (at adc_actions.py)
# 2026-01-17 15:02:08,421 [INFO] Found bus hardware ID 5: BusHardwareId(USB Bus) [bus hardware: USB BUS, protocol: MSC, hardware specifier: UsbRoot0, extra hardware specifier: UsbBusMsc] (at adc_actions.py)
# 2026-01-17 15:02:08,423 [INFO] Selected bus hardware ID: <nanotec_nanolib.Nanolib.BusHardwareId; proxy of <Swig Object of type 'nlc::BusHardwareId *' at 0x0000020A708166A0> > (at adc_actions.py)
# Scan started.
# ..
# Scan finished.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 from kspec_adc_controller.adc_actions import AdcActions
# ----> 2 controller = AdcActions()
#
# File ~\OneDrive\바탕 화면\git\kspec_adc_controller\src\kspec_adc_controller\adc_actions.py:31, in AdcActions.__init__(self, logger)
#      29 self.logger.debug("Initializing AdcActions class.")
#      30 self.controller = AdcController(self.logger)
# ---> 31 self.controller.find_devices()
#      32 self.calculator = ADCCalc(self.logger)
#
# File ~\OneDrive\바탕 화면\git\kspec_adc_controller\src\kspec_adc_controller\adc_controller.py:174, in AdcController.find_devices(self)
#     172 self.device_ids = scan_devices.getResult()
#     173 if not self.device_ids.size():
# --> 174     raise Exception("No devices found during scan.")
#     176 for i, device_id in enumerate(self.device_ids):
#     177     if i + 1 in self.devices:
#
# Exception: No devices found during scan.

# %%
controller.connect()

# %%
controller.status()

# %%
await controller.stop(1)
await controller.stop(2)

# %%
await controller.activate(60, 10)

# %%
await controller.homing(10)

# %%
await controller.zeroing(10)

# %%
await controller.activate(20, 10)

# %%
await controller.parking(10)

# %%
# motor 2 -20 -> 900 counts
await controller.move(2, -4000, 10)
# 이제 450씩 움직이면 댐

# %%
controller.disconnect()
controller.power_off()
